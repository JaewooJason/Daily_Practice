# %%
import numpy  as np
import pandas as pd

# 시각화
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

import json

import warnings
warnings.filterwarnings(action='ignore')

from datetime import date, datetime, timedelta
from dateutil.parser import parse


# 한글 폰트 문제 해결
import platform

from matplotlib import font_manager, rc

if platform.system() == 'Darwin':
    plt.rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    plt.rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')


# 차트 축 <- 음수 부호 지원
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False


# crawling
from bs4 import BeautifulSoup
from urllib.request import urlopen , urlretrieve
from urllib.error   import HTTPError
from urllib.error   import URLError

import requests
import re

print('numpy version  - ' , np.__version__)
print('pandas version - ' , pd.__version__)
# Out:
# numpy version  -  1.20.3
# pandas version -  1.3.4

# %%
html = '''
<html>
    <head>
        <title>연습</title>
    </head>
    <body>
        <h1>섭섭이와 함께하는 즐거운 스크랩핑</h1>
        <p class = 'css'>웹페이지 데이터 추출</p>
        <p id = 'data' align = 'center'>크롤링을 이용한 데이터 수집은 불법입니다.</p>
    </body>
</html>
'''

# %%
soup = BeautifulSoup(html , "html.parser")
type( soup )
# Out:
# bs4.BeautifulSoup

# %%
print('bs - find , findAll , find_all')
print('attr     - ' , soup.find('p').string )
print('function - ' , soup.find('p').get_text() )
# Out:
# bs - find , findAll , find_all
# attr     -  웹페이지 데이터 추출
# function -  웹페이지 데이터 추출

# %%
print('id 식별자로 접근 - ')
soup.find('p' , id = 'data').get_text()
# Out:
# id 식별자로 접근 -
# '크롤링을 이용한 데이터 수집은 불법입니다.'

# %%
print('class 식별자로 접근 - ')
soup.find('p' , class_ = 'css').get_text()
# Out:
# class 식별자로 접근 -
# '웹페이지 데이터 추출'

# %%
print('일반 속성을 이용한 접근 - ')
soup.find('p' , attrs = {'align' : 'center'}).get_text()
# Out:
# 일반 속성을 이용한 접근 -
# '크롤링을 이용한 데이터 수집은 불법입니다.'

# %%
webpage = requests.get('https://www.daangn.com/hot_articles')
# webpage.content
# webpage.text
soup = BeautifulSoup(webpage.content , "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=no" name="viewport"/>
# <link href="https://www.daangn.com/hot_articles" rel="canonical"/>
# <title>당근마켓 중고거래 | 당신 근처의 당근마켓</title>
# <meta content="당근마켓에서 거래되는 인기 중고 매물을 소개합니다. 지금 당근마켓에서 거래되고 있는 다양한 매물을 구경해보세요." name="description">
# <link href="당근마켓" rel="author"/>
# <meta content="https://www.daangn.com/hot_articles" property="og:url">
# <meta content="당근마켓 중고거래 | 당신 근처의 당근마켓" property="og:title">
# <meta content="당근마켓에서 거래되는 인기 중고 매물을 소개합니다. 지금 당근마켓에서 거래되고 있는 다양한 매물을 구경해보세요." property="og:description"/>
# <meta content="당근마켓" property="og:site_name"/>
# <meta content="https://www.daangn.com/images/meta/home/flea_market.png" property="og:image"/>
# <meta content="article" property="og:type"/>
# <meta content="ko_KR" property="og:locale"/>
# <meta content="1463621440622064" property="fb:app_id"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@danggeunmarket" name="twitter:site"/>
# <meta content="당근마켓 중고거래 | 당신 근처의 당근마켓" name="twitter:title"/>
# <meta content="당근마켓에서 거래되는 인기 중고 매물을 소개합니다. 지금 당근마켓에서 거래되고 있는 다양한 매물을 구경해보세요." name="twitter:description"/>
# <meta content="https://www.daangn.com/images/meta/home/flea_market.png" name="twitter:image"/>
# <meta content="d1f8112731c18313535732cf2516d6401bfed40a" name="naver-site-verification"/>
# <link href="/images/icons/shortcut_icon.png" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://d1unjqcospf8gs.cloudfront.net/favicon.ico" rel="shortcut icon" type="image/x-icon">
# <link href="https://d1unjqcospf8gs.cloudfront.net/assets/home/articles/hot-4b4ad5cdde1862f06e47a67befb6374385b790831e981e22591110798a096274.css" media="all" rel="stylesheet"/>
# <script src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base-c64d203b6861097eddabc47f94aab7527c736b1d3be0f24c56e49dd3a9201622.js"></script>
# <link href="/images/icons/daangn_logo_192.png" rel="apple-touch-icon" sizes="192x192"/>
# <link href="/images/icons/daangn_logo_192.png" rel="apple-touch-icon-precomposed"/>
# <!-- HTML5 shim and Respond.js for IE8 support of HTML5 elements and media queries -->
# <!--[if lt IE 9]>
#   <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>
#   <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>
#   <![endif]-->
# <meta content="authenticity_token" name="csrf-param"/>
# <meta content="djuyzYyzxkJHLTVFUsag5wr70bJFM8WLizjIeTcRBLo8-m98LODs9tzWz59OdE2-MmE6Ksl4_QuOidQhOBrBgQ" name="csrf-token"/>
# <script>
#     window.fbAsyncInit = function() {
#       FB.init({
#         appId      : '1463621440622064',
#         xfbml      : true,
#         version    : 'v2.4'
#       });
#     };
#
#     (function(d, s, id){
#       var js, fjs = d.getElementsByTagName(s)[0];
#       if (d.getElementById(id)) {return;}
#       js = d.createElement(s); js.id = id;
#       js.src = "//connect.facebook.net/en_US/sdk.js";
#       fjs.parentNode.insertBefore(js, fjs);
#     }(document, 'script', 'facebook-jssdk'));
#   </script>
# <script>
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#               (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#             m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#     ga('create', 'UA-64551386-2', 'auto');
#      ga('set', 'dimension2', 'false');  ga('send', 'pageview'); </script>
# <!-- Facebook Pixel Code -->
# <script>
#     !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#             n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
#       n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
#       t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
#             document,'script','//connect.facebook.net/en_US/fbevents.js');
#
#     fbq('init', '992961397411651');
#     facebookClickEvent("PageView")
#
#     function facebookClickEvent(eventName, data) {
#       if (data !== undefined) {
#           fbq('track', eventName, data)
#       } else {
#           fbq('track', eventName)
#       }
#     }
#
#     function facebookClickEventWithPageMove(eventName, data, targetUrl) {
#         facebookClickEvent(eventName, data);
#         window.location.href = targetUrl;
#     }
#   </script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=992961397411651&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- End Facebook Pixel Code -->
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#       new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#       j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#       'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#   })(window,document,'script','dataLayer','GTM-PJSK4QL');</script>
# <!-- End Google Tag Manager -->
# <script type="application/ld+json">
# {
#   "@context": "http://schema.org",
#   "@type": "Organization",
#   "name": "당근마켓",
#   "url": "https://www.daangn.com",
#   "sameAs": [
#     "https://www.facebook.com/daangn",
#     "https://blog.naver.com/daangn",
#     "https://www.youtube.com/channel/UC8tsBsQBuF7QybxgLmStihA",
#     "https://twitter.com/daangnmarket",
#     "https://www.instagram.com/daangnmarket",
#     "https://apps.apple.com/kr/app/id1018769995",
#     "https://play.google.com/store/apps/details?id=com.towneers.www"
#   ],
#   "logo": "https://www.daangn.com/logo.png"
# }
# </script>
# </link></meta></meta></meta></head>
# <body class="hoian-kr">
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-PJSK4QL" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <!-- Appsflyer Smart Banner -->
# <script>
#     !function(t,e,n,s,a,c,i,o,p){t.AppsFlyerSdkObject=a,t.AF=t.AF||function(){(t.AF.q=t.AF.q||[]).push([Date.now()].concat(Array.prototype.slice.call(arguments)))},t.AF.id=t.AF.id||i,t.AF.plugins={},o=e.createElement(n),p=e.getElementsByTagName(n)[0],o.async=1,o.src="https://websdk.appsflyer.com?"+(c.length>0?"st="+c.split(",").sort().join(",")+"&":"")+(i.length>0?"af_id="+i:""),p.parentNode.insertBefore(o,p)}(window,document,"script",0,"AF","banners",{banners: {key: "629f6f7a-a2a6-49c0-8d27-ffa48df1cd0e"}})
#     AF('banners', 'showBanner')
# </script>
# <!-- End Appsflyer Smart Banner-->
# <style>
#   #gnb-root .light-theme{--color-white: #fff;--color-gray100: #f2f3f6;--color-gray200: #eaebee;--color-gray300: #dcdee3;--color-gray400: #d1d3d8;--color-gray500: #adb1ba;--color-gray600: #868b94;--color-gray700: #4d5159;--color-gray900: #212124;--color-carrot50: #fff5f0;--color-carrot100: #ffe2d2;--color-carrot200: #ffd2b9;--color-carrot300: #ffbc97;--color-carrot400: #ff9e66;--color-carrot500: #ff7e36;--color-carrot600: #fa6616;--color-yellow50: #fff7e6;--color-yellow500: #ffc552;--color-yellow800: #ce6400;--color-green50: #e8faf6;--color-green500: #00b493;--color-green800: #008c72;--color-red50: #fff3f2;--color-red800: #e81300;--color-blue50: #ebf7fa;--color-blue800: #0a86b7;--color-background: var(--color-white);--color-background-low: var(--color-gray100)}#gnb-root .r14vym0{background:none;appearance:none;border:0;padding:0;display:flex;justify-content:center;align-items:center;cursor:pointer;white-space:nowrap}#gnb-root .r14vym1{color:var(--color-white);background-color:var(--color-carrot500)}#gnb-root .r14vym1:hover,#gnb-root .r14vym1:active{background-color:var(--color-carrot600)}#gnb-root .r14vym2{color:var(--color-carrot500);background-color:var(--color-white);border:1px solid var(--color-carrot300)}#gnb-root .r14vym2:hover,#gnb-root .r14vym2:active{background-color:var(--color-carrot100)}#gnb-root .r14vym3{color:var(--color-gray900);background-color:transparent;border:1px solid var(--color-gray400)}#gnb-root .r14vym3:hover,#gnb-root .r14vym3:active{background-color:var(--color-gray100);opacity:.7}#gnb-root .r14vym4{font-weight:700;line-height:1.32;font-size:1.8rem;letter-spacing:-2%;width:100%;min-height:5.6rem;padding:1.6rem 0;border-radius:0.6rem}#gnb-root .r14vym5{font-weight:700;line-height:1.4;font-size:1.4rem;width:100%;min-height:3.6rem;padding:0.85rem 0;border-radius:0.4rem}#gnb-root .r14vym6{font-weight:700;line-height:1.3;font-size:1.2rem;width:fit-content;min-height:2.8rem;padding:0.5rem 1rem;border-radius:0.3rem}@media screen and (min-width: 768px){#gnb-root .r14vym4{line-height:1.3;font-size:2.4rem;letter-spacing:-1%;min-height:4.8rem;padding:1.3rem 0}#gnb-root .r14vym5{line-height:1.32;font-size:1.8rem;letter-spacing:-2%}#gnb-root .r14vym6{line-height:1.5;font-size:1.3008rem}}#gnb-root ._1s38h9c0{display:flex;align-items:center}#gnb-root ._1s38h9c1{display:flex;justify-content:center}#gnb-root ._1s38h9c2{cursor:pointer;-webkit-tap-highlight-color:transparent}#gnb-root ._1s38h9c3{appearance:none;border:0;background:none;padding:0}#gnb-root ._1s38h9c4{text-decoration:none}#gnb-root ._1knjz490{background-color:var(--color-white);color:var(--color-gray900);position:fixed;top:0;left:0;width:100%;max-width:100vw;z-index:999}#gnb-root ._1knjz491{padding:1.2rem 1.6rem;height:5.6rem;box-sizing:border-box;justify-content:space-between;width:100%;margin:0 auto;position:relative}#gnb-root ._1knjz493{margin:-0.1rem 0}#gnb-root ._1knjz497{margin-right:1.6rem}#gnb-root ._1knjz498{position:absolute;left:0;width:100%;padding:0 1.6rem;box-sizing:border-box;background-color:var(--color-white)}#gnb-root ._1knjz499{display:none}#gnb-root ._1knjz49a{display:block;margin-right:1.6rem;position:relative;width:100%;box-sizing:border-box}#gnb-root ._1knjz49b{line-height:1.4;font-size:1.4rem;background-color:var(--color-gray100);box-sizing:border-box;height:4rem;padding:0.9rem 1.2rem;border:none;border-radius:0.6rem;width:100%;color:var(--color-gray900)}#gnb-root ._1knjz49b:focus{outline:0}#gnb-root ._1knjz49b::placeholder{color:var(--color-gray600)}#gnb-root ._1knjz49c{position:absolute;height:100%;top:0;right:1.2rem;display:flex;align-items:center;cursor:pointer}#gnb-root ._1knjz49d{line-height:1.36;font-size:1.6rem;color:var(--color-gray900);white-space:nowrap;cursor:pointer}#gnb-root ._1knjz49e{margin-left:0.4rem;transition:all ease .3s}#gnb-root ._1knjz49f{transform:rotate(-180deg);transition:all ease .3s}#gnb-root ._1knjz49g{flex:1}#gnb-root ._1knjz49h{font-weight:700;line-height:150%;font-size:1.4rem;padding:0.55rem 1rem;bo ...
# #footer-root .light-theme{--color-white: #fff;--color-gray100: #f2f3f6;--color-gray200: #eaebee;--color-gray300: #dcdee3;--color-gray400: #d1d3d8;--color-gray500: #adb1ba;--color-gray600: #868b94;--color-gray700: #4d5159;--color-gray900: #212124;--color-carrot50: #fff5f0;--color-carrot100: #ffe2d2;--color-carrot200: #ffd2b9;--color-carrot300: #ffbc97;--color-carrot400: #ff9e66;--color-carrot500: #ff7e36;--color-carrot600: #fa6616;--color-yellow50: #fff7e6;--color-yellow500: #ffc552;--color-yellow800: #ce6400;--color-green50: #e8faf6;--color-green500: #00b493;--color-green800: #008c72;--color-red50: #fff3f2;--color-red800: #e81300;--color-blue50: #ebf7fa;--color-blue800: #0a86b7;--color-background: var(--color-white);--color-background-low: var(--color-gray100)}#footer-root ._1s38h9c0{display:flex;align-items:center}#footer-root ._1s38h9c1{display:flex;justify-content:center}#footer-root ._1s38h9c2{cursor:pointer;-webkit-tap-highlight-color:transparent}#footer-root ._1s38h9c3{appearance:none;border:0;background:none;padding:0}#footer-root ._1s38h9c4{text-decoration:none}#footer-root ._1y9kelh0{background-color:var(--color-white);color:var(--color-gray900);padding:0 1.6rem 2rem}#footer-root ._1y9kelh0:not(:last-child){margin-bottom:0.8rem}#footer-root ._1y9kelh1{font-weight:700;line-height:1.36;font-size:1.6rem;padding:1.6rem 0}#footer-root ._1y9kelh2{max-width:76.8rem;margin:0 auto}@media screen and (min-width: 768px){#footer-root ._1y9kelh0{padding:0}#footer-root ._1y9kelh0:not(:last-child){margin-bottom:5.6rem}#footer-root ._1y9kelh1{line-height:1.3;font-size:2rem;letter-spacing:-2%}}#footer-root ._1trxeqs0{background-color:var(--color-white);color:var(--color-gray900);border-top:1px solid var(--color-gray200);padding:0 1.6rem;box-sizing:border-box;width:100%;max-width:100vw}#footer-root ._1trxeqs1{display:flex;flex-direction:column}#footer-root ._1trxeqs2{display:flex;margin-bottom:2rem}#footer-root ._1trxeqs3{font-weight:700;line-height:1.5;font-size:1.3008rem}#footer-root ._1trxeqs4{display:flex;margin-left:2.4rem}#footer-root ._1trxeqs4:not(:first-child){margin-left:1.6rem}#footer-root ._1trxeqs5{font-weight:700;line-height:1.5;font-size:1.3008rem;color:var(--color-gray900);margin-right:0.8rem}#footer-root ._1trxeqs6{color:var(--color-gray900);margin-right:0.6rem}#footer-root ._1trxeqs7{display:flex}#footer-root ._1trxeqs8{display:none}#footer-root ._1trxeqs8>svg>rect{fill:var(--color-gray100)}#footer-root ._1trxeqs8>svg>path{fill:var(--color-gray900)}#footer-root ._1trxeqs8:hover>svg>path{opacity:.5}#footer-root ._1trxeqs9{line-height:1.5;font-size:1.3008rem;display:flex;max-width:76.8rem}#footer-root ._1trxeqsa{display:flex;flex-direction:column;padding-inline-start:0;margin-block-start:0;margin-block-end:0;width:33%}#footer-root ._1trxeqsa:last-child{margin-right:15%}#footer-root ._1trxeqsb{line-height:1.3;font-size:1.2rem;margin-bottom:1.6rem;flex-wrap:wrap;color:var(--color-gray600)}#footer-root ._1trxeqsc{margin:0 0.4rem}#footer-root ._1trxeqsd{font-style:normal}#footer-root ._1trxeqse{font-weight:700;line-height:1.3;font-size:1.2rem;white-space:nowrap;color:var(--color-gray600)}#footer-root ._1trxeqse:not(:last-child){margin-right:1.6rem}#footer-root ._1trxeqse:hover{text-decoration:underline}#footer-root ._1trxeqsf{padding:4.8rem 0}#footer-root ._1trxeqsg{padding:2.4rem 0 10rem;border-top:1px solid var(--color-gray200)}#footer-root ._1trxeqsh{margin-bottom:1.6rem}#footer-root ._1trxeqsi{margin-top:2.4rem;display:flex;align-items:center}#footer-root ._1trxeqsj{padding-top:0.4rem}#footer-root ._1trxeqsj:hover{opacity:64%}#footer-root ._1trxeqsk{color:var(--color-gray600);display:flex;align-items:center;padding:0.8rem;border-radius:0.4rem;cursor:pointer}#footer-root ._1trxeqsk:hover{background-color:var(--color-gray100)}#footer-root ._1trxeqsl{background-color:var(--color-white);color:var(--color-gray600);padding-left:0.4rem;border:none;-webkit-appearance:none;-moz-appearance:none;text-indent:0.1rem;cursor:pointer}#f ...
#
# </style>
# <div id="gnb-root"><div class="light-theme"><div class="_1knjz490"><div class="_1knjz491 _1s38h9c0"><a aria-label="logo" class="_1s38h9c0" href="https://www.daangn.com"><span class="_1knjz493"><svg fill="none" height="28" viewbox="0 0 100 28" width="100" xmlns="http://www.w3.org/2000/svg"><path d="M10.6241 5.1897C4.76013 5.1897 0 9.94831 0 15.8104C0 18.2759 0.845096 20.5345 2.24209 22.3276C2.34557 22.4655 2.4663 22.6035 2.56978 22.7414C2.74225 22.9311 2.89747 23.1207 3.08719 23.3104L3.10443 23.3276C5.13956 25.4828 7.70934 27.1207 10.6068 28C13.5043 27.1207 16.0741 25.4828 18.1092 23.3276L18.1264 23.3104C18.2989 23.1207 18.4714 22.9311 18.6439 22.7414C18.7646 22.6035 18.8681 22.4655 18.9715 22.3276C20.3685 20.5345 21.2136 18.2759 21.2136 15.8104C21.2309 9.93107 16.488 5.1897 10.6241 5.1897ZM10.6241 19.8621C8.38197 19.8621 6.57105 18.0518 6.57105 15.8104C6.57105 13.569 8.38197 11.7587 10.6241 11.7587C12.8662 11.7587 14.6771 13.569 14.6771 15.8104C14.6771 18.0518 12.8662 19.8621 10.6241 19.8621Z" fill="#FF7E36"></path><path d="M14.0743 4.96552C14.7814 4.81035 15.2988 4.18965 15.2988 3.44827C15.2988 2.58621 14.5917 1.87931 13.7293 1.87931C13.4879 1.87931 13.2637 1.93104 13.0567 2.03449C12.8325 0.879318 11.8322 0 10.6076 0C9.38312 0 8.3828 0.879318 8.1586 2.03449C7.95163 1.93104 7.72742 1.87931 7.48597 1.87931C6.62363 1.87931 5.9165 2.58621 5.9165 3.44827C5.9165 4.18965 6.45116 4.81035 7.14103 4.96552C8.22758 4.58621 9.38312 4.37931 10.5904 4.37931C11.7977 4.37931 12.9877 4.58621 14.0743 4.96552Z" fill="#00B493"></path><path d="M28.8191 15.9481H35.3211C36.1317 15.9481 36.7699 15.4654 36.7699 14.4654C36.7699 13.4654 36.1317 12.9826 35.3211 12.9826H29.6642C29.371 12.9826 29.1985 12.8102 29.1985 12.5344V9.98264C29.1985 9.70678 29.371 9.53437 29.6642 9.53437H35.3211C36.1317 9.53437 36.7699 9.0516 36.7699 8.0516C36.7699 7.0516 36.1317 6.56885 35.3211 6.56885H28.8191C26.6115 6.56885 25.5767 7.5516 25.5767 9.39643V13.1378C25.5767 14.9826 26.6115 15.9481 28.8191 15.9481Z" fill="#FF7E36"></path><path d="M36.9594 17.1379H30.5608C27.6806 17.1379 25.7834 18.7241 25.7834 21.0517C25.7834 23.3276 27.6806 24.9138 30.5608 24.9138H36.9594C39.8396 24.9138 41.754 23.3276 41.754 21.0517C41.754 18.7414 39.8396 17.1379 36.9594 17.1379ZM36.9594 21.9138H30.5608C29.8537 21.9138 29.4743 21.5345 29.4743 21.0517C29.4743 20.5345 29.8537 20.1379 30.5608 20.1379H36.9594C37.6665 20.1379 38.0632 20.5345 38.0632 21.0517C38.0632 21.5345 37.6493 21.9138 36.9594 21.9138Z" fill="#FF7E36"></path><path d="M42.3754 9.60339H41.3578V7.65512C41.3578 6.81029 40.6162 6.17236 39.5469 6.17236C38.4776 6.17236 37.7188 6.81029 37.7188 7.65512V15.2068C37.7188 16.0517 38.4776 16.6896 39.5469 16.6896C40.6162 16.6896 41.3578 16.0517 41.3578 15.2068V13.1551H42.3754C43.2032 13.1551 43.8586 12.431 43.8586 11.3965C43.8586 10.3965 43.2032 9.60339 42.3754 9.60339Z" fill="#FF7E36"></path><path d="M60.5189 17.6206H45.6693C44.807 17.6206 44.0999 17.0516 44.0999 15.9999C44.0999 15.0171 44.807 14.4137 45.6693 14.4137H60.5189C61.3812 14.4137 62.0883 15.0344 62.0883 15.9999C62.0883 17.0344 61.3812 17.6206 60.5189 17.6206ZM57.4662 12.3964V10.4654C57.4662 10.1206 57.2764 9.93092 56.9833 9.93092H46.6869C45.79 9.93092 45.0312 9.36194 45.0312 8.27574C45.0312 7.24125 45.79 6.56885 46.6869 6.56885H57.7766C59.9842 6.56885 61.1052 7.70678 61.1052 9.72402V12.3964C61.1052 13.2413 60.3636 13.8792 59.2943 13.8792C58.225 13.8792 57.4662 13.2413 57.4662 12.3964ZM48.7565 19.7068V20.9826C48.7565 21.2413 48.9462 21.4137 49.2394 21.4137H59.829C60.7258 21.4137 61.4847 21.9999 61.4847 23.0688C61.4847 24.1033 60.7258 24.724 59.829 24.724H48.4633C46.273 24.724 45.1002 23.793 45.1002 21.8102V19.7068C45.1002 18.8619 45.8418 18.224 46.9111 18.224C47.9804 18.224 48.7565 18.8619 48.7565 19.7068Z" fill="#FF7E36"></path><path d="M63.9343 21.362V9.12063C63.9343 7.44822 64.7794 6.56891 66.5214 6.56891H71.2642C73.0062 6.56891 73.8513 7.43098 73.8513 9.12063V21.362C73.8513 23.0344 73.0062 23.9137 71.2642 23.9137H66.5214C64.7967 23.9 ...
# <script charset="utf-8" type="text/javascript">
#     (()=>{var af=Object.create;var bl=Object.defineProperty,cf=Object.defineProperties,ff=Object.getOwnPropertyDescriptor,pf=Object.getOwnPropertyDescriptors,df=Object.getOwnPropertyNames,Xu=Object.getOwnPropertySymbols,mf=Object.getPrototypeOf,bu=Object.prototype.hasOwnProperty,hf=Object.prototype.propertyIsEnumerable;var Ju=(e,t,n)=>t in e?bl(e,t,{enumerable:!0,configurable:!0,writable:!0,value:n}):e[t]=n,It=(e,t)=>{for(var n in t||(t={}))bu.call(t,n)&&Ju(e,n,t[n]);if(Xu)for(var n of Xu(t))hf.call(t,n)&&Ju(e,n,t[n]);return e},Vt=(e,t)=>cf(e,pf(t));var ie=(e,t)=>()=>(t||e((t={exports:{}}).exports,t),t.exports);var vf=(e,t,n,r)=>{if(t&&typeof t=="object"||typeof t=="function")for(let l of df(t))!bu.call(e,l)&&l!==n&&bl(e,l,{get:()=>t[l],enumerable:!(r=ff(t,l))||r.enumerable});return e};var R=(e,t,n)=>(n=e!=null?af(mf(e)):{},vf(t||!e||!e.__esModule?bl(n,"default",{value:e,enumerable:!0}):n,e));var es=(e,t,n)=>new Promise((r,l)=>{var o=s=>{try{u(n.next(s))}catch(a){l(a)}},i=s=>{try{u(n.throw(s))}catch(a){l(a)}},u=s=>s.done?r(s.value):Promise.resolve(s.value).then(o,i);u((n=n.apply(e,t)).next())});var fs=ie(L=>{"use strict";var yn=Symbol.for("react.element"),gf=Symbol.for("react.portal"),yf=Symbol.for("react.fragment"),Cf=Symbol.for("react.strict_mode"),Ef=Symbol.for("react.profiler"),wf=Symbol.for("react.provider"),xf=Symbol.for("react.context"),kf=Symbol.for("react.forward_ref"),Sf=Symbol.for("react.suspense"),_f=Symbol.for("react.memo"),Nf=Symbol.for("react.lazy"),ts=Symbol.iterator;function Pf(e){return e===null||typeof e!="object"?null:(e=ts&&e[ts]||e["@@iterator"],typeof e=="function"?e:null)}var ls={isMounted:function(){return!1},enqueueForceUpdate:function(){},enqueueReplaceState:function(){},enqueueSetState:function(){}},os=Object.assign,is={};function jt(e,t,n){this.props=e,this.context=t,this.refs=is,this.updater=n||ls}jt.prototype.isReactComponent={};jt.prototype.setState=function(e,t){if(typeof e!="object"&&typeof e!="function"&&e!=null)throw Error("setState(...): takes an object of state variables to update or a function which returns an object of state variables.");this.updater.enqueueSetState(this,e,t,"setState")};jt.prototype.forceUpdate=function(e){this.updater.enqueueForceUpdate(this,e,"forceUpdate")};function us(){}us.prototype=jt.prototype;function to(e,t,n){this.props=e,this.context=t,this.refs=is,this.updater=n||ls}var no=to.prototype=new us;no.constructor=to;os(no,jt.prototype);no.isPureReactComponent=!0;var ns=Array.isArray,ss=Object.prototype.hasOwnProperty,ro={current:null},as={key:!0,ref:!0,__self:!0,__source:!0};function cs(e,t,n){var r,l={},o=null,i=null;if(t!=null)for(r in t.ref!==void 0&&(i=t.ref),t.key!==void 0&&(o=""+t.key),t)ss.call(t,r)&&!as.hasOwnProperty(r)&&(l[r]=t[r]);var u=arguments.length-2;if(u===1)l.children=n;else if(1<u){for(var s=Array(u),a=0;a<u;a++)s[a]=arguments[a+2];l.children=s}if(e&&e.defaultProps)for(r in u=e.defaultProps,u)l[r]===void 0&&(l[r]=u[r]);return{$$typeof:yn,type:e,key:o,ref:i,props:l,_owner:ro.current}}function Lf(e,t){return{$$typeof:yn,type:e.type,key:t,ref:e.ref,props:e.props,_owner:e._owner}}function lo(e){return typeof e=="object"&&e!==null&&e.$$typeof===yn}function Tf(e){var t={"=":"=0",":":"=2"};return"$"+e.replace(/[=:]/g,function(n){return t[n]})}var rs=/\/+/g;function eo(e,t){return typeof e=="object"&&e!==null&&e.key!=null?Tf(""+e.key):t.toString(36)}function Sr(e,t,n,r,l){var o=typeof e;(o==="undefined"||o==="boolean")&&(e=null);var i=!1;if(e===null)i=!0;else switch(o){case"string":case"number":i=!0;break;case"object":switch(e.$$typeof){case yn:case gf:i=!0}}if(i)return i=e,l=l(i),e=r===""?"."+eo(i,0):r,ns(l)?(n="",e!=null&&(n=e.replace(rs,"$&/")+"/"),Sr(l,t,n,"",function(a){return a})):l!=null&&(lo(l)&&(l=Lf(l,n+(!l.key||i&&i.key===l.key?"":(""+l.key).replace(rs,"$&/")+"/")+e)),t.push(l)),1;if(i=0,r=r===""?".":r+":",ns(e))for(var u=0;u<e.length;u++){o=e[u];var s=r+eo(o,u);i+=Sr(o,t,n,s,l)}else if(s=Pf(e),typeof s=="function")for(e=s.call(e),u=0;!(o=e.n ...
# `+ho+e}var vo=!1;function go(e,t){if(!e||vo)return"";vo=!0;var n=Error.prepareStackTrace;Error.prepareStackTrace=void 0;try{if(t)if(t=function(){throw Error()},Object.defineProperty(t.prototype,"props",{set:function(){throw Error()}}),typeof Reflect=="object"&&Reflect.construct){try{Reflect.construct(t,[])}catch(a){var r=a}Reflect.construct(e,[],t)}else{try{t.call()}catch(a){r=a}e.call(t.prototype)}else{try{throw Error()}catch(a){r=a}e()}}catch(a){if(a&&r&&typeof a.stack=="string"){for(var l=a.stack.split(`
# `),o=r.stack.split(`
# `),i=l.length-1,u=o.length-1;1<=i&&0<=u&&l[i]!==o[u];)u--;for(;1<=i&&0<=u;i--,u--)if(l[i]!==o[u]){if(i!==1||u!==1)do if(i--,u--,0>u||l[i]!==o[u]){var s=`
# `+l[i].replace(" at new "," at ");return e.displayName&&s.includes("<anonymous>")&&(s=s.replace("<anonymous>",e.displayName)),s}while(1<=i&&0<=u);break}}}finally{vo=!1,Error.prepareStackTrace=n}return(e=e?e.displayName||e.name:"")?Rn(e):""}function jf(e){switch(e.tag){case 5:return Rn(e.type);case 16:return Rn("Lazy");case 13:return Rn("Suspense");case 19:return Rn("SuspenseList");case 0:case 2:case 15:return e=go(e.type,!1),e;case 11:return e=go(e.type.render,!1),e;case 1:return e=go(e.type,!0),e;default:return""}}function Ao(e){if(e==null)return null;if(typeof e=="function")return e.displayName||e.name||null;if(typeof e=="string")return e;switch(e){case Bt:return"Fragment";case At:return"Portal";case jo:return"Profiler";case Ti:return"StrictMode";case Fo:return"Suspense";case Ho:return"SuspenseList"}if(typeof e=="object")switch(e.$$typeof){case Va:return(e.displayName||"Context")+".Consumer";case Ia:return(e._context.displayName||"Context")+".Provider";case Mi:var t=e.render;return e=e.displayName,e||(e=t.displayName||t.name||"",e=e!==""?"ForwardRef("+e+")":"ForwardRef"),e;case Ri:return t=e.displayName||null,t!==null?t:Ao(e.type)||"Memo";case Je:t=e._payload,e=e._init;try{return Ao(e(t))}catch(n){}}return null}function Ff(e){var t=e.type;switch(e.tag){case 24:return"Cache";case 9:return(t.displayName||"Context")+".Consumer";case 10:return(t._context.displayName||"Context")+".Provider";case 18:return"DehydratedFragment";case 11:return e=t.render,e=e.displayName||e.name||"",t.displayName||(e!==""?"ForwardRef("+e+")":"ForwardRef");case 7:return"Fragment";case 5:return t;case 4:return"Portal";case 3:return"Root";case 6:return"Text";case 16:return Ao(t);case 8:return t===Ti?"StrictMode":"Mode";case 22:return"Offscreen";case 12:return"Profiler";case 21:return"Scope";case 13:return"Suspense";case 19:return"SuspenseList";case 25:return"TracingMarker";case 1:case 0:case 17:case 2:case 14:case 15:if(typeof t=="function")return t.displayName||t.name||null;if(typeof t=="string")return t}return null}function ct(e){switch(typeof e){case"boolean":case"number":case"string":case"undefined":return e;case"object":return e;default:return""}}function Fa(e){var t=e.type;return(e=e.nodeName)&&e.toLowerCase()==="input"&&(t==="checkbox"||t==="radio")}function Hf(e){var t=Fa(e)?"checked":"value",n=Object.getOwnPropertyDescriptor(e.constructor.prototype,t),r=""+e[t];if(!e.hasOwnProperty(t)&&typeof n!="undefined"&&typeof n.get=="function"&&typeof n.set=="function"){var l=n.get,o=n.set;return Object.defineProperty(e,t,{configurable:!0,get:function(){return l.call(this)},set:function(i){r=""+i,o.call(this,i)}}),Object.defineProperty(e,t,{enumerable:n.enumerable}),{getValue:function(){return r},setValue:function(i){r=""+i},stopTracking:function(){e._valueTracker=null,delete e[t]}}}}function Or(e){e._valueTracker||(e._valueTracker=Hf(e))}function Ha(e){if(!e)return!1;var t=e._valueTracker;if(!t)return!0;var n=t.getValue(),r="";return e&&(r=Fa(e)?e.checked?"true":"false":e.value),e=r,e!==n?(t.setValue(e),!0):!1}function sl(e){if(e=e||(typeof document!="undefined"?document:void 0),typeof e=="undefined")return null;try{return e.activeElement||e.body}catch(t){return e.body}}function Bo(e,t){var n=t.checked;return B({},t,{defaultChecked:void 0,defaultValue:void 0,value:void 0,checked:n!=null?n:e._wrapperState.initialChecked})}function Ls(e,t){var n=t.defaultValue==null?"":t.defaultValue,r=t.checked!=null?t.checked:t.defaultChecked;n=ct(t.value!=null?t.value:n),e._wrapperState={initialChecked:r,initialValue:n,controlled:t.type==="checkbox"||t.type==="radio"?t.checked!=null:t.value!=null}}function Aa(e,t){t=t.checked,t!=null&&Li(e,"checked",t,!1)}function Uo(e,t){Aa(e,t);var n=ct(t.value),r=t.type;if(n!=null)r==="number"?(n===0&&e.value===""||e.value!=n)&&(e.value=""+n):e.value!==""+n&&(e.value=""+n);else if(r==="submit"||r==="reset"){e.removeAttribute("value");return}t.hasOwnProperty("value")?$o(e,t.type,n):t.hasOwnProperty("defaultValue")&&$o(e,t.type,ct(t.def ...
# `).replace(Q0,"")}function Zr(e,t,n){if(t=bs(t),bs(e)!==t&&n)throw Error(v(425))}function hl(){}var ri=null;function li(e,t){return e==="textarea"||e==="noscript"||typeof t.children=="string"||typeof t.children=="number"||typeof t.dangerouslySetInnerHTML=="object"&&t.dangerouslySetInnerHTML!==null&&t.dangerouslySetInnerHTML.__html!=null}var oi=typeof setTimeout=="function"?setTimeout:void 0,K0=typeof clearTimeout=="function"?clearTimeout:void 0,ea=typeof Promise=="function"?Promise:void 0,G0=typeof queueMicrotask=="function"?queueMicrotask:typeof ea!="undefined"?function(e){return ea.resolve(null).then(e).catch(Y0)}:oi;function Y0(e){setTimeout(function(){throw e})}function Po(e,t){var n=t,r=0;do{var l=n.nextSibling;if(e.removeChild(n),l&&l.nodeType===8)if(n=l.data,n==="/$"){if(r===0){e.removeChild(l),Kn(t);return}r--}else n!=="$"&&n!=="$?"&&n!=="$!"||r++;n=l}while(n);Kn(t)}function Be(e){for(;e!=null;e=e.nextSibling){var t=e.nodeType;if(t===1||t===3)break;if(t===8){if(t=e.data,t==="$"||t==="$!"||t==="$?")break;if(t==="/$")return null}}return e}function ta(e){e=e.previousSibling;for(var t=0;e;){if(e.nodeType===8){var n=e.data;if(n==="$"||n==="$!"||n==="$?"){if(t===0)return e;t--}else n==="/$"&&t++}e=e.previousSibling}return null}var dn=Math.random().toString(36).slice(2),Oe="__reactFiber$"+dn,bn="__reactProps$"+dn,qe="__reactContainer$"+dn,ii="__reactEvents$"+dn,X0="__reactListeners$"+dn,J0="__reactHandles$"+dn;function Ct(e){var t=e[Oe];if(t)return t;for(var n=e.parentNode;n;){if(t=n[qe]||n[Oe]){if(n=t.alternate,t.child!==null||n!==null&&n.child!==null)for(e=ta(e);e!==null;){if(n=e[Oe])return n;e=ta(e)}return t}e=n,n=e.parentNode}return null}function ar(e){return e=e[Oe]||e[qe],!e||e.tag!==5&&e.tag!==6&&e.tag!==13&&e.tag!==3?null:e}function Wt(e){if(e.tag===5||e.tag===6)return e.stateNode;throw Error(v(33))}function jl(e){return e[bn]||null}var ui=[],qt=-1;function mt(e){return{current:e}}function F(e){0>qt||(e.current=ui[qt],ui[qt]=null,qt--)}function I(e,t){qt++,ui[qt]=e.current,e.current=t}var ft={},te=mt(ft),ce=mt(!1),_t=ft;function ln(e,t){var n=e.type.contextTypes;if(!n)return ft;var r=e.stateNode;if(r&&r.__reactInternalMemoizedUnmaskedChildContext===t)return r.__reactInternalMemoizedMaskedChildContext;var l={},o;for(o in n)l[o]=t[o];return r&&(e=e.stateNode,e.__reactInternalMemoizedUnmaskedChildContext=t,e.__reactInternalMemoizedMaskedChildContext=l),l}function fe(e){return e=e.childContextTypes,e!=null}function vl(){F(ce),F(te)}function na(e,t,n){if(te.current!==ft)throw Error(v(168));I(te,t),I(ce,n)}function P1(e,t,n){var r=e.stateNode;if(t=t.childContextTypes,typeof r.getChildContext!="function")return n;r=r.getChildContext();for(var l in r)if(!(l in t))throw Error(v(108,Ff(e)||"Unknown",l));return B({},n,r)}function gl(e){return e=(e=e.stateNode)&&e.__reactInternalMemoizedMergedChildContext||ft,_t=te.current,I(te,e),I(ce,ce.current),!0}function ra(e,t,n){var r=e.stateNode;if(!r)throw Error(v(169));n?(e=P1(e,t,_t),r.__reactInternalMemoizedMergedChildContext=e,F(ce),F(te),I(te,e)):F(ce),I(ce,n)}var Ae=null,Fl=!1,Lo=!1;function L1(e){Ae===null?Ae=[e]:Ae.push(e)}function b0(e){Fl=!0,L1(e)}function ht(){if(!Lo&&Ae!==null){Lo=!0;var e=0,t=O;try{var n=Ae;for(O=1;e<n.length;e++){var r=n[e];do r=r(!0);while(r!==null)}Ae=null,Fl=!1}catch(l){throw Ae!==null&&(Ae=Ae.slice(e+1)),e1(Di,ht),l}finally{O=t,Lo=!1}}return null}var ep=Ke.ReactCurrentBatchConfig;function Le(e,t){if(e&&e.defaultProps){t=B({},t),e=e.defaultProps;for(var n in e)t[n]===void 0&&(t[n]=e[n]);return t}return t}var yl=mt(null),Cl=null,Qt=null,Ui=null;function $i(){Ui=Qt=Cl=null}function Zi(e){var t=yl.current;F(yl),e._currentValue=t}function si(e,t,n){for(;e!==null;){var r=e.alternate;if((e.childLanes&t)!==t?(e.childLanes|=t,r!==null&&(r.childLanes|=t)):r!==null&&(r.childLanes&t)!==t&&(r.childLanes|=t),e===n)break;e=e.return}}function tn(e,t){Cl=e,Ui=Qt=null,e=e.dependencies,e!==null&&e.firstContext!==null&&((e.lanes&t)!==0&&(me=!0),e.firstContext=null)}functio ...
# Error generating stack: `+o.message+`
# `+o.stack}return{value:e,source:t,stack:l}}function di(e,t){try{console.error(t.value)}catch(n){setTimeout(function(){throw n})}}var sp=typeof WeakMap=="function"?WeakMap:Map;function tc(e,t,n){n=Ze(-1,n),n.tag=3,n.payload={element:null};var r=t.value;return n.callback=function(){Ll||(Ll=!0,xi=r),di(e,t)},n}function nc(e,t,n){n=Ze(-1,n),n.tag=3;var r=e.type.getDerivedStateFromError;if(typeof r=="function"){var l=t.value;n.payload=function(){return r(l)},n.callback=function(){di(e,t)}}var o=e.stateNode;return o!==null&&typeof o.componentDidCatch=="function"&&(n.callback=function(){di(e,t),typeof r!="function"&&(st===null?st=new Set([this]):st.add(this));var i=t.stack;this.componentDidCatch(t.value,{componentStack:i!==null?i:""})}),n}function fa(e,t,n){var r=e.pingCache;if(r===null){r=e.pingCache=new sp;var l=new Set;r.set(t,l)}else l=r.get(t),l===void 0&&(l=new Set,r.set(t,l));l.has(n)||(l.add(n),e=xp.bind(null,e,t,n),t.then(e,e))}function pa(e){do{var t;if((t=e.tag===13)&&(t=e.memoizedState,t=t!==null?t.dehydrated!==null:!0),t)return e;e=e.return}while(e!==null);return null}function da(e,t,n,r,l){return(e.mode&1)===0?(e===t?e.flags|=65536:(e.flags|=128,n.flags|=131072,n.flags&=-52805,n.tag===1&&(n.alternate===null?n.tag=17:(t=Ze(-1,1),t.tag=2,ut(n,t))),n.lanes|=1),e):(e.flags|=65536,e.lanes=l,e)}var rc,mi,lc,oc;rc=function(e,t){for(var n=t.child;n!==null;){if(n.tag===5||n.tag===6)e.appendChild(n.stateNode);else if(n.tag!==4&&n.child!==null){n.child.return=n,n=n.child;continue}if(n===t)break;for(;n.sibling===null;){if(n.return===null||n.return===t)return;n=n.return}n.sibling.return=n.return,n=n.sibling}};mi=function(){};lc=function(e,t,n,r){var l=e.memoizedProps;if(l!==r){e=t.stateNode,Et(Ie.current);var o=null;switch(n){case"input":l=Bo(e,l),r=Bo(e,r),o=[];break;case"select":l=B({},l,{value:void 0}),r=B({},r,{value:void 0}),o=[];break;case"textarea":l=Zo(e,l),r=Zo(e,r),o=[];break;default:typeof l.onClick!="function"&&typeof r.onClick=="function"&&(e.onclick=hl)}qo(n,r);var i;n=null;for(a in l)if(!r.hasOwnProperty(a)&&l.hasOwnProperty(a)&&l[a]!=null)if(a==="style"){var u=l[a];for(i in u)u.hasOwnProperty(i)&&(n||(n={}),n[i]="")}else a!=="dangerouslySetInnerHTML"&&a!=="children"&&a!=="suppressContentEditableWarning"&&a!=="suppressHydrationWarning"&&a!=="autoFocus"&&($n.hasOwnProperty(a)?o||(o=[]):(o=o||[]).push(a,null));for(a in r){var s=r[a];if(u=l!=null?l[a]:void 0,r.hasOwnProperty(a)&&s!==u&&(s!=null||u!=null))if(a==="style")if(u){for(i in u)!u.hasOwnProperty(i)||s&&s.hasOwnProperty(i)||(n||(n={}),n[i]="");for(i in s)s.hasOwnProperty(i)&&u[i]!==s[i]&&(n||(n={}),n[i]=s[i])}else n||(o||(o=[]),o.push(a,n)),n=s;else a==="dangerouslySetInnerHTML"?(s=s?s.__html:void 0,u=u?u.__html:void 0,s!=null&&u!==s&&(o=o||[]).push(a,s)):a==="children"?typeof s!="string"&&typeof s!="number"||(o=o||[]).push(a,""+s):a!=="suppressContentEditableWarning"&&a!=="suppressHydrationWarning"&&($n.hasOwnProperty(a)?(s!=null&&a==="onScroll"&&j("scroll",e),o||u===s||(o=[])):(o=o||[]).push(a,s))}n&&(o=o||[]).push("style",n);var a=o;(t.updateQueue=a)&&(t.flags|=4)}};oc=function(e,t,n,r){n!==r&&(t.flags|=4)};function Ln(e,t){if(!H)switch(e.tailMode){case"hidden":t=e.tail;for(var n=null;t!==null;)t.alternate!==null&&(n=t),t=t.sibling;n===null?e.tail=null:n.sibling=null;break;case"collapsed":n=e.tail;for(var r=null;n!==null;)n.alternate!==null&&(r=n),n=n.sibling;r===null?t||e.tail===null?e.tail=null:e.tail.sibling=null:r.sibling=null}}function b(e){var t=e.alternate!==null&&e.alternate.child===e.child,n=0,r=0;if(t)for(var l=e.child;l!==null;)n|=l.lanes|l.childLanes,r|=l.subtreeFlags&14680064,r|=l.flags&14680064,l.return=e,l=l.sibling;else for(l=e.child;l!==null;)n|=l.lanes|l.childLanes,r|=l.subtreeFlags,r|=l.flags,l.return=e,l=l.sibling;return e.subtreeFlags|=r,e.childLanes=n,t}function ap(e,t,n){var r=t.pendingProps;switch(Qi(t),t.tag){case 2:case 16:case 15:case 0:case 11:case 7:case 8:case 12:case 9:case 14:return b(t),null;case 1:return fe(t.type)&&vl(),b(t),n ...
# /**
#  * @license React
#  * react-dom.production.min.js
#  *
#  * Copyright (c) Facebook, Inc. and its affiliates.
#  *
#  * This source code is licensed under the MIT license found in the
#  * LICENSE file in the root directory of this source tree.
#  */
# /**
#  * @license React
#  * react-jsx-runtime.production.min.js
#  *
#  * Copyright (c) Facebook, Inc. and its affiliates.
#  *
#  * This source code is licensed under the MIT license found in the
#  * LICENSE file in the root directory of this source tree.
#  */
# /**
#  * @license React
#  * react.production.min.js
#  *
#  * Copyright (c) Facebook, Inc. and its affiliates.
#  *
#  * This source code is licensed under the MIT license found in the
#  * LICENSE file in the root directory of this source tree.
#  */
# /**
#  * @license React
#  * scheduler.production.min.js
#  *
#  * Copyright (c) Facebook, Inc. and its affiliates.
#  *
#  * This source code is licensed under the MIT license found in the
#  * LICENSE file in the root directory of this source tree.
#  */
#
# </script>
# <section id="content">
# <h1 class="head-title" id="hot-articles-head-title">
#
#
#       중고거래 인기매물
#   </h1>
# <nav id="hot-articles-navigation">
# <select class="hot-articles-nav-select" id="region1" name="region1" onchange="changeRegion('r1', this.value, false)"><option value="">지역을 선택하세요</option><option value="서울특별시">서울특별시</option>
# <option value="부산광역시">부산광역시</option>
# <option value="대구광역시">대구광역시</option>
# <option value="인천광역시">인천광역시</option>
# <option value="광주광역시">광주광역시</option>
# <option value="대전광역시">대전광역시</option>
# <option value="울산광역시">울산광역시</option>
# <option value="세종특별자치시">세종특별자치시</option>
# <option value="경기도">경기도</option>
# <option value="강원도">강원도</option>
# <option value="충청북도">충청북도</option>
# <option value="충청남도">충청남도</option>
# <option value="전라북도">전라북도</option>
# <option value="전라남도">전라남도</option>
# <option value="경상북도">경상북도</option>
# <option value="경상남도">경상남도</option>
# <option value="제주특별자치도">제주특별자치도</option></select>
# <select class="hot-articles-nav-select" disabled="disabled" id="region2" name="region2" onchange="changeRegion('r2', this.value, false)"><option value="">동네를 선택하세요</option><option value="서울특별시">서울특별시</option>
# <option value="부산광역시">부산광역시</option>
# <option value="대구광역시">대구광역시</option>
# <option value="인천광역시">인천광역시</option>
# <option value="광주광역시">광주광역시</option>
# <option value="대전광역시">대전광역시</option>
# <option value="울산광역시">울산광역시</option>
# <option value="세종특별자치시">세종특별자치시</option>
# <option value="경기도">경기도</option>
# <option value="강원도">강원도</option>
# <option value="충청북도">충청북도</option>
# <option value="충청남도">충청남도</option>
# <option value="전라북도">전라북도</option>
# <option value="전라남도">전라남도</option>
# <option value="경상북도">경상북도</option>
# <option value="경상남도">경상남도</option>
# <option value="제주특별자치도">제주특별자치도</option></select>
# </nav>
# <section class="cards-wrap">
# <article class="card-top">
# <a class="card-link" data-event-label="424238006" href="/articles/424238006">
# <div class="card-photo">
# <img alt="케리어제습기2015년형(15L)" src="https://dnvefa72aowie.cloudfront.net/origin/article/202206/d70702f9e6a9c49aa88e4a589d8c528f11aff9f2d6559faeadc5da717917a543.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">케리어제습기2015년형(15L)</h2>
# <div class="card-price">
#         200,000원
#       </div>
# <div class="card-region-name">
#         부산 연제구 연산제9동
#       </div>
# <div class="card-counts">
# <span>
#             관심 21
#           </span>
#         ∙
#         <span>
#             채팅 68
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="425896779" href="/articles/425896779">
# <div class="card-photo">
# <img alt="(종료)아이스크림 창고 정리!! 박스당 8천원!!" src="https://dnvefa72aowie.cloudfront.net/origin/article/202206/B68CF6AA492741D0C89D5E5F8044E18F5F13697883BA09783B5ED45444E64504.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">(종료)아이스크림 창고 정리!! 박스당 8천원!!</h2>
# <div class="card-price">
#         8,000원
#       </div>
# <div class="card-region-name">
#         경남 밀양시 산외면
#       </div>
# <div class="card-counts">
# <span>
#             관심 28
#           </span>
#         ∙
#         <span>
#             채팅 98
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="426381830" href="/articles/426381830">
# <div class="card-photo">
# <img alt="제습기 팔아요" src="https://dnvefa72aowie.cloudfront.net/origin/article/202207/fec4d09f1251ca82aeede0cd659588c751f7bb22ba4cb5e0c00f991cda4ad0ef.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">제습기 팔아요</h2>
# <div class="card-price">
#         30,000원
#       </div>
# <div class="card-region-name">
#         서울 중랑구 면목제2동
#       </div>
# <div class="card-counts">
# <span>
#             관심 6
#           </span>
#         ∙
#         <span>
#             채팅 24
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="425575400" href="/articles/425575400">
# <div class="card-photo">
# <img alt="포켓몬빵 종류별로 1300원에 팔아요 ( 냉장은 별도)" src="https://dnvefa72aowie.cloudfront.net/origin/article/202206/980C1C0948BA04ED85D837C42456000508F3FFC565325101661F39024328973B.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">포켓몬빵 종류별로 1300원에 팔아요 ( 냉장은 별도)</h2>
# <div class="card-price">
#         1,300원
#       </div>
# <div class="card-region-name">
#         대전 서구 관저2동
#       </div>
# <div class="card-counts">
# <span>
#             관심 63
#           </span>
#         ∙
#         <span>
#             채팅 113
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="426195650" href="/articles/426195650">
# <div class="card-photo">
# <img alt="위닉스 제습기" src="https://dnvefa72aowie.cloudfront.net/origin/article/202206/e18ec03181960174b6778f6be758a7478bf693f7219028dde7dd23e8d23b7dbb.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">위닉스 제습기</h2>
# <div class="card-price">
#         50,000원
#       </div>
# <div class="card-region-name">
#         부산 해운대구 반여동
#       </div>
# <div class="card-counts">
# <span>
#             관심 9
#           </span>
#         ∙
#         <span>
#             채팅 36
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="424307388" href="/articles/424307388">
# <div class="card-photo">
# <img alt="건조기,냉장고,티비,세탁기,에어컨 정리합니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202206/03c773515a4dac8f1ba340fde15186d96a6486f8bfe2fa1117a6e3b1fe2275e3.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">건조기,냉장고,티비,세탁기,에어컨 정리합니다</h2>
# <div class="card-price">
#         10원
#       </div>
# <div class="card-region-name">
#         충남 서산시 석림동
#       </div>
# <div class="card-counts">
# <span>
#             관심 32
#           </span>
#         ∙
#         <span>
#             채팅 69
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="426204380" href="/articles/426204380">
# <div class="card-photo">
# <img alt="쿠잉 미니 냉장고" src="https://dnvefa72aowie.cloudfront.net/origin/article/202206/d2e83ec1f898c21de0e32fcd08d778990fa2dc66a05d81fde3fb89c1b7c06515.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">쿠잉 미니 냉장고</h2>
# <div class="card-price">
#         30,000원
#       </div>
# <div class="card-region-name">
#         경남 양산시 동면
#       </div>
# <div class="card-counts">
# <span>
#             관심 11
#           </span>
#         ∙
#         <span>
#             채팅 19
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="424313985" href="/articles/424313985">
# <div class="card-photo">
# <img alt="자작나무 원목 캣타워" src="https://dnvefa72aowie.cloudfront.net/origin/article/202206/2e9c240a7c798d9d71556e79fc1e63cfcb9fce4c29b75820541ed6ef44180e63.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">자작나무 원목 캣타워</h2>
# <div class="card-price">
#         45,000원
#       </div>
# <div class="card-region-name">
#         인천 남동구 구월2동
#       </div>
# <div class="card-counts">
# <span>
#             관심 50
#           </span>
#         ∙
#         <span>
#             채팅 51
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="426345711" href="/articles/426345711">
# <div class="card-photo">
# <img alt="야외테이블" src="https://dnvefa72aowie.cloudfront.net/origin/article/202207/0749cbf315d5c1e79ffefae41b1be2edbeb604c96a0ee91ed8fa06094f14c2d8.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">야외테이블</h2>
# <div class="card-price blank-price">
# </div>
# <div class="card-region-name">
#         제주 서귀포시 성산읍
#       </div>
# <div class="card-counts">
# <span>
#             관심 6
#           </span>
#         ∙
#         <span>
#             채팅 28
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="426494654" href="/articles/426494654">
# <div class="card-photo">
# <img alt="위닉스 뽀송 제습기 DHC-085ING" src="https://dnvefa72aowie.cloudfront.net/origin/article/202207/31c2aed171918b428eae14639819220d3d8cd24322e87112b97a282cba202174.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">위닉스 뽀송 제습기 DHC-085ING</h2>
# <div class="card-price">
#         60,000원
#       </div>
# <div class="card-region-name">
#         인천 미추홀구 주안6동
#       </div>
# <div class="card-counts">
# <span>
#             관심 7
#           </span>
#         ∙
#         <span>
#             채팅 17
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="426378830" href="/articles/426378830">
# <div class="card-photo">
# <img alt="LG제습기" src="https://dnvefa72aowie.cloudfront.net/origin/article/202207/14152a92cc5dc70a6870e0a28e8f4238b8b50898276374c753fd9e927374f102.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">LG제습기</h2>
# <div class="card-price">
#         150,000원
#       </div>
# <div class="card-region-name">
#         경기도 성남시 분당구 구미동
#       </div>
# <div class="card-counts">
# <span>
#             관심 9
#           </span>
#         ∙
#         <span>
#             채팅 24
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="425688967" href="/articles/425688967">
# <div class="card-photo">
# <img alt="필링스 제습기 팝니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202206/A53E7BE68B2CA3AB57C8A2EDED3BA22F43A72373158BD9C7F5A4C2A0C90825BB.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">필링스 제습기 팝니다</h2>
# <div class="card-price">
#         20,000원
#       </div>
# <div class="card-region-name">
#         부산 해운대구 우제3동
#       </div>
# <div class="card-counts">
# <span>
#             관심 6
#           </span>
#         ∙
#         <span>
#             채팅 33
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="426383402" href="/articles/426383402">
# <div class="card-photo">
# <img alt="1인가구용 냉장고 팝니다." src="https://dnvefa72aowie.cloudfront.net/origin/article/202207/B33A82B777C8EEA3C1580F6DC97BF81C78BFC59D2E542D7D21A70A3181B348C9.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">1인가구용 냉장고 팝니다.</h2>
# <div class="card-price">
#         20,000원
#       </div>
# <div class="card-region-name">
#         경기도 화성시 향남읍
#       </div>
# <div class="card-counts">
# <span>
#             관심 3
#           </span>
#         ∙
#         <span>
#             채팅 18
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="426415578" href="/articles/426415578">
# <div class="card-photo">
# <img alt="위닉스 제습기 10L(21년 7월 생산) 10만원에 팝니다" src="https://dnvefa72aowie.cloudfront.net/origin/article/202207/78f12d6500aaac51f0e8b9fac8b07df4a7f6f4aec694b55f85b29f8dd5e3e64e.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">위닉스 제습기 10L(21년 7월 생산) 10만원에 팝니다</h2>
# <div class="card-price">
#         100,000원
#       </div>
# <div class="card-region-name">
#         서울 동작구 사당제2동
#       </div>
# <div class="card-counts">
# <span>
#             관심 10
#           </span>
#         ∙
#         <span>
#             채팅 16
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="426248996" href="/articles/426248996">
# <div class="card-photo">
# <img alt="컴퓨터 팝니다~~" src="https://dnvefa72aowie.cloudfront.net/origin/article/202206/ACD164A8D44D6BAEBFD6BD0ED2F165185D4CFE39FE555A993ACAEC1896B78118.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# ...
#       </div>
# <div class="card-counts">
# <span>
#             관심 6
#           </span>
#         ∙
#         <span>
#             채팅 8
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="425337967" href="/articles/425337967">
# <div class="card-photo">
# <img alt="일렉기타(스윙)" src="https://dnvefa72aowie.cloudfront.net/origin/article/202206/e46dd0e605f1aeb30d2790eae297222295ebfa9f3f5e66c15114eea91dc41281.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">일렉기타(스윙)</h2>
# <div class="card-price">
#         30,000원
#       </div>
# <div class="card-region-name">
#         서울 양천구 신정1동
#       </div>
# <div class="card-counts">
# <span>
#             관심 12
#           </span>
#         ∙
#         <span>
#             채팅 13
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="426414020" href="/articles/426414020">
# <div class="card-photo">
# <img alt="가정용 철제 폴딩선반 팔아요 새제품 미세하자" src="https://dnvefa72aowie.cloudfront.net/origin/article/202207/4EC3B949A0BBC35725AE53531B2053C796737B52253434EB8AB58954AB24EB3C.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">가정용 철제 폴딩선반 팔아요 새제품 미세하자</h2>
# <div class="card-price">
#         15,000원
#       </div>
# <div class="card-region-name">
#         인천 서구 가좌동
#       </div>
# <div class="card-counts">
# <span>
#             관심 22
#           </span>
#         ∙
#         <span>
#             채팅 16
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="426571534" href="/articles/426571534">
# <div class="card-photo">
# <img alt="친환경 감자 담아가세요~" src="https://dnvefa72aowie.cloudfront.net/origin/article/202207/C08B2E2B302D5DC818EDDA513A9675E452ADBEAAB6F3BB8169CB15DC6969B6FA.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">친환경 감자 담아가세요~</h2>
# <div class="card-price">
#         1,000원
#       </div>
# <div class="card-region-name">
#         전북 군산시 수송동
#       </div>
# <div class="card-counts">
# <span>
#             관심 34
#           </span>
#         ∙
#         <span>
#             채팅 11
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="426501650" href="/articles/426501650">
# <div class="card-photo">
# <img alt="리모와 캐리어 에센셜" src="https://dnvefa72aowie.cloudfront.net/origin/article/202207/67392B467D4A23DC41E254F895236FD5144A1506BA4A6F6837F593043FA7E554.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">리모와 캐리어 에센셜</h2>
# <div class="card-price">
#         450,000원
#       </div>
# <div class="card-region-name">
#         서울 강남구 압구정동
#       </div>
# <div class="card-counts">
# <span>
#             관심 14
#           </span>
#         ∙
#         <span>
#             채팅 8
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="423596992" href="/articles/423596992">
# <div class="card-photo">
# <img alt="선풍기.&lt;한일&gt;" src="https://dnvefa72aowie.cloudfront.net/origin/article/202206/7f468c33c67e48dc803ed9af7357c5cee0a7a3ae1db375666709d141c58fe113.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">선풍기.&lt;한일&gt;</h2>
# <div class="card-price">
#         10,000원
#       </div>
# <div class="card-region-name">
#         경기도 안산시 상록구 성포동
#       </div>
# <div class="card-counts">
# <span>
#             관심 15
#           </span>
#         ∙
#         <span>
#             채팅 35
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="426366040" href="/articles/426366040">
# <div class="card-photo">
# <img alt="동양매직 제습기 10리터" src="https://dnvefa72aowie.cloudfront.net/origin/article/202207/13adac671209bed53baa982f771d38671df6d746c7903f8940cf3e0393ae700c.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">동양매직 제습기 10리터</h2>
# <div class="card-price">
#         20,000원
#       </div>
# <div class="card-region-name">
#         경기도 안산시 단원구 고잔동
#       </div>
# <div class="card-counts">
# <span>
#             관심 5
#           </span>
#         ∙
#         <span>
#             채팅 12
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="426020086" href="/articles/426020086">
# <div class="card-photo">
# <img alt="제습기" src="https://dnvefa72aowie.cloudfront.net/origin/article/202206/173E2F50E1D65BA495FEA47928BA52F2B0B7771BE58FFCCE669DFDA58893607D.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">제습기</h2>
# <div class="card-price">
#         30,000원
#       </div>
# <div class="card-region-name">
#         제주 제주시 조천읍
#       </div>
# <div class="card-counts">
# <span>
#             관심 1
#           </span>
#         ∙
#         <span>
#             채팅 23
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="426561837" href="/articles/426561837">
# <div class="card-photo">
# <img alt="선풍기 두달사용" src="https://dnvefa72aowie.cloudfront.net/origin/article/202207/abb49b3bfbfd709559f0b797fc13fc338ce62dac3730b9d4c485ef3fac2312f2.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">선풍기 두달사용</h2>
# <div class="card-price">
#         15,000원
#       </div>
# <div class="card-region-name">
#         대구 달서구 이곡1동
#       </div>
# <div class="card-counts">
# <span>
#             관심 10
#           </span>
#         ∙
#         <span>
#             채팅 13
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="426236498" href="/articles/426236498">
# <div class="card-photo">
# <img alt="아이폰 13 프로" src="https://dnvefa72aowie.cloudfront.net/origin/article/202207/529829871591e005b3c8e0b7db70d3b8fc6de6b1780f308d12bfa8fd23c7702b.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">아이폰 13 프로</h2>
# <div class="card-price">
#         600,000원
#       </div>
# <div class="card-region-name">
#         서울 강동구 성내제2동
#       </div>
# <div class="card-counts">
# <span>
#             관심 15
#           </span>
#         ∙
#         <span>
#             채팅 27
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="426208641" href="/articles/426208641">
# <div class="card-photo">
# <img alt="선풍기" src="https://dnvefa72aowie.cloudfront.net/origin/article/202206/B7D90070FAEE4F93794C160099C52910CE74ED5C2D331CC5A24D56165DB72264.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">선풍기</h2>
# <div class="card-price">
#         5,000원
#       </div>
# <div class="card-region-name">
#         경북 김천시 부곡동
#       </div>
# <div class="card-counts">
# <span>
#             관심 4
#           </span>
#         ∙
#         <span>
#             채팅 14
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="426468674" href="/articles/426468674">
# <div class="card-photo">
# <img alt="다이슨 선풍기" src="https://dnvefa72aowie.cloudfront.net/origin/article/202207/3654394BA4C62DECDB043EF35709A2E8278A81B151555CAB2E13A722575C2AD5.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">다이슨 선풍기</h2>
# <div class="card-price">
#         95,000원
#       </div>
# <div class="card-region-name">
#         서울 서초구 서초4동
#       </div>
# <div class="card-counts">
# <span>
#             관심 1
#           </span>
#         ∙
#         <span>
#             채팅 13
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="425565748" href="/articles/425565748">
# <div class="card-photo">
# <img alt="헌터, 어그 레인부츠" src="https://dnvefa72aowie.cloudfront.net/origin/article/202206/7c8d5d81c8a7a4f240eee04661244364711cc3f2c1775abbacc437e616a614ca.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">헌터, 어그 레인부츠</h2>
# <div class="card-price">
#         50,000원
#       </div>
# <div class="card-region-name">
#         서울 서초구 반포본동
#       </div>
# <div class="card-counts">
# <span>
#             관심 40
#           </span>
#         ∙
#         <span>
#             채팅 36
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="426552741" href="/articles/426552741">
# <div class="card-photo">
# <img alt="천마차" src="https://dnvefa72aowie.cloudfront.net/origin/article/202207/B78E477B2542B3713CE88885D20FE713724EE0994B5412BD685C7DD880CCB7D7.jpg?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">천마차</h2>
# <div class="card-price">
#         3,000원
#       </div>
# <div class="card-region-name">
#         세종시  다정동
#       </div>
# <div class="card-counts">
# <span>
#             관심 3
#           </span>
#         ∙
#         <span>
#             채팅 14
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="426350525" href="/articles/426350525">
# <div class="card-photo">
# <img alt="벽걸이 선풍기 리모컨포함" src="https://dnvefa72aowie.cloudfront.net/origin/article/202207/c02e710501c5ca6625e5808032312863684fe200b77719d2a02438a1b6eb9490.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">벽걸이 선풍기 리모컨포함</h2>
# <div class="card-price">
#         15,000원
#       </div>
# <div class="card-region-name">
#         서울 구로구 구로제5동
#       </div>
# <div class="card-counts">
# <span>
#             관심 2
#           </span>
#         ∙
#         <span>
#             채팅 14
#           </span>
# </div>
# </div>
# </a></article>
# <article class="card-top">
# <a class="card-link" data-event-label="426570470" href="/articles/426570470">
# <div class="card-photo">
# <img alt="제습기 팔아요" src="https://dnvefa72aowie.cloudfront.net/origin/article/202207/b164ef1db43ea1f43a96396a25587e81cce3bb25396f5c6d6d6c2e6157c9638d.webp?q=82&amp;s=300x300&amp;t=crop"/>
# </div>
# <div class="card-desc">
# <h2 class="card-title">제습기 팔아요</h2>
# <div class="card-price">
#         20,000원
#       </div>
# <div class="card-region-name">
#         대구 수성구 만촌1동
#       </div>
# <div class="card-counts">
# <span>
#             관심 2
#           </span>
#         ∙
#         <span>
#             채팅 12
#           </span>
# </div>
# </div>
# </a></article>
# </section>
# <section id="hot-articles-go-download">
# <h3>
#         더 구경하고 싶나요?
#     </h3>
# <p>당근마켓 앱에서 따뜻한 거래를 직접 경험해보세요!</p>
# <div id="hot-articles-download-buttons">
# <a class="download-button" href="https://itunes.apple.com/kr/app/pangyojangteo/id1018769995?l=ko&amp;ls=1&amp;mt=8" target="_blank">
# <div class="home-apple-store-bar-white"></div>
# <div class="download-text">App Store</div>
# </a> <a class="download-button" href="https://play.google.com/store/apps/details?id=com.towneers.www" target="_blank">
# <div class="home-google-play-bar-white"></div>
# <div class="download-text">Google Play</div>
# </a> </div>
# </section>
# </section>
# <script charset="utf-8" type="text/javascript">
#   function changeRegion(key, value, is_group_article_page){
#     var url_array
#     if(window.location.pathname === "/hot_articles" && window.location.href.match(/\?/)) {
#       url_array = window.location.href.split('?')[1].split(/(?:r1|&?r2)=/)
#       url_array.unshift("")
#     } else {
#       url_array = window.location.pathname.split('/')
#       if(is_group_article_page) {
#           url_array.splice(1,2) // remove 'group_articles/:gid'
#       }
#     }
#     var keys = { r1: 2, r2: 3, r3: 4 }
#     url_array[keys[key]] = value
#     url_array[1] = 'region'
#       if(key == 'r2' && decodeURI(url_array[2]) == "세종특별자치시") {
#         url_array[4] = value
#         url_array[3] = "_"
#       }
#     if(key == 'r1') { url_array.splice(3, 2) }
#     if(key == 'r2' && url_array[3] !== "_") { url_array.splice(4, 1) }
#     if(is_group_article_page) {
#         window.location.href = window.location.origin + window.location.pathname.split('/').slice(0,3).concat(url_array.slice(1)).join('/')
#     } else {
#         window.location.href = window.location.origin + url_array.join('/')
#     }
#   }
# </script>
# <footer id="footer">
# <div class="footer-container">
# <div class="footer-top">
# <div class="footer-logo"></div>
# <ul class="footer-list">
# <li class="footer-list-item"><a class="link-highlight" href="/trust">믿을 수 있는 중고거래</a></li>
# <li class="footer-list-item"><a class="link-highlight" href="https://cs.kr.karrotmarket.com/wv/faqs">자주 묻는 질문</a></li>
# </ul>
# <ul class="footer-list">
# <li class="footer-list-item"><a class="link-highlight" href="https://ads-local.daangn.com" target="_blank">광고주센터</a></li>
# <li class="footer-list-item">
# <a href="https://daangnpay.com" target="_blank">당근페이</a>
# <li class="footer-list-item">
# <a class="ga-click" data-event-action="hot_articles" data-event-category="town_link_from" data-event-label="footer_town" href="https://town.daangn.com" target="_blank">동네가게</a>
# </li>
# </li></ul>
# <ul class="footer-list">
# <li class="footer-list-item"><a href="https://team.daangn.com/" target="_blank">회사 소개</a></li>
# <li class="footer-list-item"><a href="https://team.daangn.com/jobs/" target="_blank">채용</a></li>
# </ul>
# <ul class="footer-list policy">
# <li class="footer-list-item"><a href="https://policy.daangn.com/terms.html" target="_blank">이용약관</a></li>
# <li class="footer-list-item"><b><a href="https://policy.daangn.com/privacy.html" target="_blank">개인정보처리방침</a></b></li>
# <li class="footer-list-item"><a href="https://policy.daangn.com/location.html" target="_blank">위치기반서비스 이용약관</a></li>
# <li class="footer-list-item"><a href="https://www.daangn.com/wv/faqs/3994" target="_blank">이용자보호 비전과 계획</a></li>
# </ul>
# </div>
# <div class="footer-bottom">
# <div id="copyright">
# <ul class="copyright-list">
# <li class="copyright-list-item">고객문의 <a href="mailto:cs@daangnservice.com">cs@daangnservice.com</a></li>
# <li class="copyright-list-item">제휴문의 <a href="mailto:contact@daangn.com">contact@daangn.com</a></li>
# </ul>
# <ul class="copyright-list">
# <li class="copyright-list-item">광고 <a href="mailto:ad@daangn.com">ad@daangn.com</a></li>
# <li class="copyright-list-item">PR문의 <a href="mailto:pr@daangn.com">pr@daangn.com</a></li>
# <li class="copyright-list-item">IR문의 <a href="mailto:ir@daangn.com">ir@daangn.com</a></li>
# </ul>
# <ul class="copyright-list copyright-list-light">
# <li class="copyright-list-item"><address>서울특별시 구로구 디지털로30길 28, 609호 (당근서비스)</address></li>
# <li class="copyright-list-item">사업자 등록번호 : 375-87-00088</li>
# <li class="copyright-list-item">직업정보제공사업 신고번호 : J1200020200016</li>
# </ul>
# <div id="social">
# <ul class="social-list">
# <li class="social-list-item">
# <a class="footer-social-link" href="https://www.facebook.com/daangn" target="_blank">
# <img alt="facebook" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/footer/icon-facebook-0563f4a93852d073b41f13b8bcabb03d47af3bb3a6755cdfedd8a73686c7f18c.svg"/>
# <span class="sr-only">facebook</span>
# </a> </li>
# <li class="social-list-item">
# <a class="footer-social-link" href="https://www.instagram.com/daangnmarket/" target="_blank">
# <img alt="instagram" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/footer/icon-instagram-2f6c88a461597907c114b7ce28eab053fcae791ed26417915fefb6f7c9f95756.svg"/>
# <span class="sr-only">instagram</span>
# </a> </li>
# <li class="social-list-item">
# <a class="footer-social-link" href="https://blog.naver.com/daangn" target="_blank">
# <img alt="blog" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/footer/icon-blog-e1b0d512d1766a6962ec5bbb5b0803d2a6a9c55ad97db5ba9eebb76013caceba.svg"/>
# <span class="sr-only">blog</span>
# </a> </li>
# <li class="global-links">
# <img alt="country" height="24" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/footer/icon-global-2f53678b428ec623cefd07a90dd7777f3e55fc0433918f645d7d75ace6ff1fc3.png" width="24"/>
# <select id="global-links-select">
# <option value="kr">한국</option>
# <option value="https://uk.karrotmarket.com">영국</option>
# <option value="https://ca.karrotmarket.com">캐나다</option>
# <option value="https://us.karrotmarket.com">미국</option>
# <option value="https://jp.karrotmarket.com">일본</option>
# </select>
# </li>
# </ul>
# </div>
# <div class="copyright-text">©Danggeun Market Inc.</div>
# </div>
# </div>
# </div>
# </footer>
# </body>
# </html>

# %%
print('태그 탐색 - ')
print('<p>    - ' , soup.p , soup.find('p'))
print('string - ' , soup.p.string)
# Out:
# 태그 탐색 -
# <p>    -  <p>당근마켓 앱에서 따뜻한 거래를 직접 경험해보세요!</p> <p>당근마켓 앱에서 따뜻한 거래를 직접 경험해보세요!</p>
# string -  당근마켓 앱에서 따뜻한 거래를 직접 경험해보세요!

# %%
print('<h1>    - '  , soup.h1 , soup.find('h1'))
print('string  - '  , soup.h1.string)
for txt in soup.h1.children :
    print(txt)
# Out:
# <h1>    -  <h1 class="head-title" id="hot-articles-head-title">
#
#
#       중고거래 인기매물
#   </h1> <h1 class="head-title" id="hot-articles-head-title">
#
#
#       중고거래 인기매물
#   </h1>
# string  -
#
#
#       중고거래 인기매물
#
#
#
#
#       중고거래 인기매물

# %%
print('<h1>    - '  , soup.h1 , soup.find('h1'))
print('string  - '  , soup.h1.string)
for txt in soup.h1.children :
    print(txt)
# Out:
# <h1>    -  <h1 class="head-title" id="hot-articles-head-title">
#
#
#       중고거래 인기매물
#   </h1> <h1 class="head-title" id="hot-articles-head-title">
#
#
#       중고거래 인기매물
#   </h1>
# string  -
#
#
#       중고거래 인기매물
#
#
#
#
#       중고거래 인기매물

# %%
print('<h1>    - '  , soup.h1 , soup.find('h1'))
print('string  - '  , soup.h1.string)
for txt in soup.h1.children :
    print(txt)
# Out:
# <h1>    -  <h1 class="head-title" id="hot-articles-head-title">
#
#
#       중고거래 인기매물
#   </h1> <h1 class="head-title" id="hot-articles-head-title">
#
#
#       중고거래 인기매물
#   </h1>
# string  -
#
#
#       중고거래 인기매물
#
#
#
#
#       중고거래 인기매물

# %%
print('class 속성을 활용해서 card-title 만 가져온다면 - ')
print()

# soup.findAll(class_ = 'card-title')
# card = soup.find_all(class_='card-title')
# card_titles = soup.findAll(class_ = 'card-title')


for title in soup.find_all('h2' , attrs = {'class' : 'card-title'}) :
    print(title.string)
# Out:
# class 속성을 활용해서 card-title 만 가져온다면 -
#
# 케리어제습기2015년형(15L)
# (종료)아이스크림 창고 정리!! 박스당 8천원!!
# 제습기 팔아요
# 포켓몬빵 종류별로 1300원에 팔아요 ( 냉장은 별도)
# 위닉스 제습기
# 건조기,냉장고,티비,세탁기,에어컨 정리합니다
# 쿠잉 미니 냉장고
# 자작나무 원목 캣타워
# 야외테이블
# 위닉스 뽀송 제습기 DHC-085ING
# LG제습기
# 필링스 제습기 팝니다
# 1인가구용 냉장고 팝니다.
# 위닉스 제습기 10L(21년 7월 생산) 10만원에 팝니다
# 컴퓨터 팝니다~~
# 엘지 제습기
# 캐리어 제습기 (13리터)
# 참치캔 12캔씩
# 제습기
# 접이식 자전거 드려요
# 아이폰12 프로 팝니다 (iphone12 pro,아이폰 12프로)
# 선반
# 감자 담아가세요~
# 스팸 클래식 200그램(유통기한 22.10.8)
# 삼성 제습기
# 위닉스 제습기 2012년형
# 냉장고
# 에어 써큘레이터
# 미니냉장고
# 전자레인지
# 엘지 tv
# 위니아 제습기 8L판매합니다
# 자전거 팔아요(답이 좀 늦을수있어요)
# 5단 선반
# 젝시오 여성 아이언세트
# 코렐 6인 세트
# 자전거 팝니다.
# 아이폰 13미니
# 급처) 컴퓨터 본체 팜 모니터 서비스
# 선풍기 저렴하게 가지고 가세요(2대)
# 전자레인지
# 위닉스 제습기
# 야외 파라솔&철제 테이블 의자 세트
# 제습기 팝니다
# 파쎄코 써큘레이터 (한달사용)paseco pcf-m20000w
# 냉장고
# 야외창고
# 위닉스제습기10l
# 전기자전거
# 휘센 제습기 팝니다
# 에어컨
# 이케아 헬메르 서랍장 레드
# 위니아 제습기 10L <dalw100-hwk> 팝니다!
# 에어팟 프로 급처합니다!
# 노비타 11L 제습기
# 아이폰 11
# 제습기
# 스탠드리모컨선풍기
# 위니아 제습기 판매합니다
# 냉장고 7만원에 가져가세요~^^
# 선풍기 8인치 에어 써큘레이터 새제품 판매
# 저 내일 생일이에여!!!
# 골프채
# 냉장고,쇼파,세탁기 팔아요~
# 20kg 쌀  드림
# PSP 배터리고장(소장용) 판매합니다.
# LG 냉장고 (M349SE) 판매합니다
# 위닉스 뽀송 제습기 16리터
# 웅진 제습기
# 냉장고 세탁기 일괄
# LG 휘센 제습기
# 위닉스 제습기
# 다이슨 드라이기 미사용
# 위닉스 제습기
# 위닉스 제습기
# (새상품)스타우브
# 위닉스 제습기
# 냉장고 팝니다
# [건담/건프라/프라모델] 판매 합니다
# 쌀10kg
# 🍑🍑🍑 올해 마지막 복숭아 팔아요! 🍑🍑🍑
# 파세코 이동식 에어컨 팝니다
# 제습기
# 냉장고 팝니다(세제품) 급처 포장은 제거됬는데  사용안했습니다
# 일렉기타(스윙)
# 가정용 철제 폴딩선반 팔아요 새제품 미세하자
# 친환경 감자 담아가세요~
# 리모와 캐리어 에센셜
# 선풍기.<한일>
# 동양매직 제습기 10리터
# 제습기
# 선풍기 두달사용
# 아이폰 13 프로
# 선풍기
# 다이슨 선풍기
# 헌터, 어그 레인부츠
# 천마차
# 벽걸이 선풍기 리모컨포함
# 제습기 팔아요

# %%
print( 'type - ' , type( soup.select('.card-title') ))
print()
print( soup.select('.card-title') )
# Out:
# type -  <class 'bs4.element.ResultSet'>
#
# [<h2 class="card-title">케리어제습기2015년형(15L)</h2>, <h2 class="card-title">(종료)아이스크림 창고 정리!! 박스당 8천원!!</h2>, <h2 class="card-title">제습기 팔아요</h2>, <h2 class="card-title">포켓몬빵 종류별로 1300원에 팔아요 ( 냉장은 별도)</h2>, <h2 class="card-title">위닉스 제습기</h2>, <h2 class="card-title">건조기,냉장고,티비,세탁기,에어컨 정리합니다</h2>, <h2 class="card-title">쿠잉 미니 냉장고</h2>, <h2 class="card-title">자작나무 원목 캣타워</h2>, <h2 class="card-title">야외테이블</h2>, <h2 class="card-title">위닉스 뽀송 제습기 DHC-085ING</h2>, <h2 class="card-title">LG제습기</h2>, <h2 class="card-title">필링스 제습기 팝니다</h2>, <h2 class="card-title">1인가구용 냉장고 팝니다.</h2>, <h2 class="card-title">위닉스 제습기 10L(21년 7월 생산) 10만원에 팝니다</h2>, <h2 class="card-title">컴퓨터 팝니다~~</h2>, <h2 class="card-title">엘지 제습기</h2>, <h2 class="card-title">캐리어 제습기 (13리터)</h2>, <h2 class="card-title">참치캔 12캔씩</h2>, <h2 class="card-title">제습기</h2>, <h2 class="card-title">접이식 자전거 드려요</h2>, <h2 class="card-title">아이폰12 프로 팝니다 (iphone12 pro,아이폰 12프로)</h2>, <h2 class="card-title">선반</h2>, <h2 class="card-title">감자 담아가세요~</h2>, <h2 class="card-title">스팸 클래식 200그램(유통기한 22.10.8)</h2>, <h2 class="card-title">삼성 제습기</h2>, <h2 class="card-title">위닉스 제습기 2012년형</h2>, <h2 class="card-title">냉장고</h2>, <h2 class="card-title">에어 써큘레이터</h2>, <h2 class="card-title">미니냉장고</h2>, <h2 class="card-title">전자레인지</h2>, <h2 class="card-title">엘지 tv</h2>, <h2 class="card-title">위니아 제습기 8L판매합니다</h2>, <h2 class="card-title">자전거 팔아요(답이 좀 늦을수있어요)</h2>, <h2 class="card-title">5단 선반</h2>, <h2 class="card-title">젝시오 여성 아이언세트</h2>, <h2 class="card-title">코렐 6인 세트</h2>, <h2 class="card-title">자전거 팝니다.</h2>, <h2 class="card-title">아이폰 13미니</h2>, <h2 class="card-title">급처) 컴퓨터 본체 팜 모니터 서비스</h2>, <h2 class="card-title">선풍기 저렴하게 가지고 가세요(2대)</h2>, <h2 class="card-title">전자레인지</h2>, <h2 class="card-title">위닉스 제습기</h2>, <h2 class="card-title">야외 파라솔&amp;철제 테이블 의자 세트</h2>, <h2 class="card-title">제습기 팝니다</h2>, <h2 class="card-title">파쎄코 써큘레이터 (한달사용)paseco pcf-m20000w</h2>, <h2 class="card-title">냉장고</h2>, <h2 class="card-title">야외창고</h2>, <h2 class="card-title">위닉스제습기10l</h2>, <h2 class="card-title">전기자전거</h2>, <h2 class="card-title">휘센 제습기 팝니다</h2>, <h2 class="card-title">에어컨</h2>, <h2 class="card-title">이케아 헬메르 서랍장 레드</h2>, <h2 class="card-title">위니아 제습기 10L &lt;dalw100-hwk&gt; 팝니다!</h2>, <h2 class="card-title">에어팟 프로 급처합니다!</h2>, <h2 class="card-title">노비타 11L 제습기</h2>, <h2 class="card-title">아이폰 11</h2>, <h2 class="card-title">제습기</h2>, <h2 class="card-title">스탠드리모컨선풍기</h2>, <h2 class="card-title">위니아 제습기 판매합니다</h2>, <h2 class="card-title">냉장고 7만원에 가져가세요~^^</h2>, <h2 class="card-title">선풍기 8인치 에어 써큘레이터 새제품 판매</h2>, <h2 class="card-title">저 내일 생일이에여!!!</h2>, <h2 class="card-title">골프채</h2>, <h2 class="card-title">냉장고,쇼파,세탁기 팔아요~</h2>, <h2 class="card-title">20kg 쌀  드림</h2>, <h2 class="card-title">PSP 배터리고장(소장용) 판매합니다.</h2>, <h2 class="card-title">LG 냉장고 (M349SE) 판매합니다</h2>, <h2 class="card-title">위닉스 뽀송 제습기 16리터</h2>, <h2 class="card-title">웅진 제습기</h2>, <h2 class="card-title">냉장고 세탁기 일괄</h2>, <h2 class="card-title">LG 휘센 제습기</h2>, <h2 class="card-title">위닉스 제습기</h2>, <h2 class="card-title">다이슨 드라이기 미사용</h2>, <h2 class="card-title">위닉스 제습기</h2>, <h2 class="card-title">위닉스 제습기</h2>, <h2 class="card-title">(새상품)스타우브</h2>, <h2 class="card-title">위닉스 제습기</h2>, <h2 class="card-title">냉장고 팝니다</h2>, <h2 class="card-title">[건담/건프라/프라모델] 판매 합니다</h2>, <h2 class="card-title">쌀10kg</h2>, <h2 class="card-title">🍑🍑🍑 올해 마지막 복숭아 팔아요! 🍑🍑🍑</h2>, <h2 class="card-title">파세코 이동식 에어컨 팝니다</h2>, <h2 class="card-title">제습기</h2>, <h2 class="card-title">냉장고 팝니다(세제품) 급처 포장은 제거됬는데  사용안했습니다</h2>, <h2 class="card-title">일렉기타(스윙)</h2>, <h2 class="card-title">가정용 철제 폴딩선반 팔아요 새제품 미세하자</h2>, <h2 class="card-title">친환경 감자 담아가세요~</h2>, <h2 class="card-title">리모와 캐리어 에센셜</h2>, <h2 class="card-title">선풍기.&lt;한일&gt;</h2>, <h2 class="card-title">동양매직 제습기 10리터</h2>, <h2 class="card-title">제습기</h2>, <h2 class="card-title">선풍기 두달사용</h2>, <h2 class="card-title">아이폰 13 프로</h2>, <h2 class="card-title">선풍기</h2>, <h2 class="card-title">다이슨 선풍기</h ...

# %%
print( soup.select('#hot-articles-go-download > div > a' ) )
print()
for a in soup.select('#hot-articles-go-download > div > a' ) :
    print(a)
    print()
# Out:
# [<a class="download-button" href="https://itunes.apple.com/kr/app/pangyojangteo/id1018769995?l=ko&amp;ls=1&amp;mt=8" target="_blank">
# <div class="home-apple-store-bar-white"></div>
# <div class="download-text">App Store</div>
# </a>, <a class="download-button" href="https://play.google.com/store/apps/details?id=com.towneers.www" target="_blank">
# <div class="home-google-play-bar-white"></div>
# <div class="download-text">Google Play</div>
# </a>]
#
# <a class="download-button" href="https://itunes.apple.com/kr/app/pangyojangteo/id1018769995?l=ko&amp;ls=1&amp;mt=8" target="_blank">
# <div class="home-apple-store-bar-white"></div>
# <div class="download-text">App Store</div>
# </a>
#
# <a class="download-button" href="https://play.google.com/store/apps/details?id=com.towneers.www" target="_blank">
# <div class="home-google-play-bar-white"></div>
# <div class="download-text">Google Play</div>
# </a>

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

try :
    html = urlopen('http://www.pythonscraping.com/pages/page3.html')
except HTTPError as he :
    print('http error')
except URLError as ue :
    print('url error')
else :
    # print(html.read())
    soup = BeautifulSoup(html.read() , 'html.parser')

# %%
# type( soup.select('#giftList') )
print('type - ' , type( soup.find('table' , attrs = {'id' : 'giftList'}) ) )
print()
table = soup.find('table' , attrs = {'id' : 'giftList'})
# Out:
# type -  <class 'bs4.element.Tag'>

# %%
print('title, desc, cost, img 데이터 추출 후')
print('데이터 프레임으로 만들어 본다면? - ')
print()

title_lst = []
desc_lst  = []
cost_lst  = []
img_lst   = []

datas = []
for trs in table.find_all('tr') :

    # print(tr)
    # print('*' * 50)
    # print( trs.find_all('td'))

    tds = trs.find_all('td')

    for td in tds :
        if td.find('img') :
            title_lst.append( tds[0].get_text().strip() )

            desc_lst.append(  tds[1].get_text().strip() )

            cost_lst.append(  tds[2].get_text().strip() )

            img_lst.append(   tds[3].find('img')['src'] )

#             print( tds[0].get_text().strip() )
#             print( tds[1].get_text().strip() )
#             print( tds[2].get_text().strip() )
#             print( tds[3].find('img')['src'] )
#             print("*" * 50)

#             datas.append([tds[0].get_text().strip() , tds[1].get_text().strip() , tds[2].get_text().strip() , tds[3].find('img')['src']])
# Out:
# title, desc, cost, img 데이터 추출 후
# 데이터 프레임으로 만들어 본다면? -

# %%
scraping_frm = pd.DataFrame({
    'title' : title_lst ,
    'desc'  : desc_lst ,
    'cost'  : cost_lst ,
    'img'   : img_lst
})
scraping_frm
# Out:
#                    title                                               desc  \
# 0       Vegetable Basket  This vegetable basket is the perfect gift for ...
# 1  Russian Nesting Dolls  Hand-painted by trained monkeys, these exquisi...
# 2          Fish Painting  If something seems fishy about this painting, ...
# 3            Dead Parrot  This is an ex-parrot! Or maybe he's only resting?
# 4            Mystery Box  If you love suprises, this mystery box is for ...
#
#          cost                    img
# 0      $15.00  ../img/gifts/img1.jpg
# 1  $10,000.52  ../img/gifts/img2.jpg
# 2  $10,005.00  ../img/gifts/img3.jpg
# 3       $0.50  ../img/gifts/img4.jpg
# 4       $1.50  ../img/gifts/img6.jpg
